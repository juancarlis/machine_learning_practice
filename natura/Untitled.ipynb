# %%
import pandas as pd
import numpy as np

# %%
df_regulares = pd.read_csv('data/raw/clean_ItemsRegulares.csv')
df_registro_materiales = pd.read_csv('data/raw/clean_RegistroMateriales.csv', sep='|')

# %%
df_regulares.head(5)
# Out:
#                                  ID  CODIGO_VENTA  MATERIAL    CICLO  \
# 0  000ed0002c5d4d0e5b9deb813976e577          3698  50335274   202115
# 1  001f3a2f541c7cf28a19c0af35146f03         86944  50283782  202114b
# 2  0022b81734ca5f89aecaa2128969912a         92596  50264617  202114b
# 3  002faadfe44cf116dde83c2c374360f9         70825  50349665   202115
# 4  003213441eba84028ea7df262404d9bc        109942  50364715   202115
#
#       SUBCICLO FECHA_CAPTACION                 TIPO  UNIDADES VENTA ONLINE  \
# 0          NaN      2021-10-26  Venta com Descuento         1           Sí
# 1  2o SubCiclo      2021-10-25              Reclamo         1           No
# 2  2o SubCiclo      2021-10-25         Venta Normal        51           No
# 3          NaN      2021-10-25         Venta Normal         4           No
# 4          NaN      2021-10-26              Reclamo         1           No
#
#    COD_LINEA_SEPARACION                               LINEA_SEPARACION  \
# ...

# %%
df_registro_materiales.head(5)
# Out:
#    Material                           Descripción  Unidades por caja  \
# 0  50000092        ESTUCHE REPICKING NAVIDAD 2005                  0
# 1  50000093            DEMO-FOLH PRIM/VERAO - INT                  0
# 2  50000133           BIOGRAFIA-CJ PROMOCIONAL 99                  0
# 3  50000224               SOMBRA EM BASTAO-PEROLA                  0
# 4  50000225  DEMO LABIALES EXTREMO CONFORT VARIOS                  0
#
#    Peso (g)  Volumen (cm3)  Coste medio  Coste última reposición
# 0        76            190           14                       14
# 1         1              1            0                        0
# 2         1              1            0                        0
# 3        15             53            2                        1
# 4        20             20            1                        1
